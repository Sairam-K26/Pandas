# %%
import pandas as pd

# %%
df=pd.read_csv('/content/sample_data/anscombe.json')

# %%
df.head()
# Out:
#                                        [
#   {"Series":"I"  "X":10.0  "Y":8.04} NaN
#                  "X":8.0   "Y":6.95} NaN
#                  "X":13.0  "Y":7.58} NaN
#                  "X":9.0   "Y":8.81} NaN
#                  "X":11.0  "Y":8.33} NaN

# %%
f=pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
f.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
f['longitude']
# Out:
# 0      -122.05
# 1      -118.30
# 2      -117.81
# 3      -118.36
# 4      -119.67
#          ...
# 2995   -119.86
# 2996   -118.14
# 2997   -119.70
# 2998   -117.12
# 2999   -119.63
# Name: longitude, Length: 3000, dtype: float64

# %%
f['households']
# Out:
# 0        606.0
# 1        277.0
# 2        495.0
# 3         11.0
# 4        237.0
#          ...
# 2995     607.0
# 2996    1036.0
# 2997     220.0
# 2998      14.0
# 2999     260.0
# Name: households, Length: 3000, dtype: float64

# %%
f.info('')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
f.info
# Out:
# <bound method DataFrame.info of       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
f.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
f[1:3]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
#
#    population  households  median_income  median_house_value
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0

# %%
f.loc[1:3,['longitude']]
# Out:
#    longitude
# 1    -118.30
# 2    -117.81
# 3    -118.36

# %%
t=f[f['latitude']>30.06]

# %%
t
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
m=t.stack()

# %%
m
# Out:
# 0     longitude               -122.0500
#       latitude                  37.3700
#       housing_median_age        27.0000
#       total_rooms             3885.0000
#       total_bedrooms           661.0000
#                                ...
# 2999  total_bedrooms           263.0000
#       population               753.0000
#       households               260.0000
#       median_income              8.5608
#       median_house_value    500001.0000
# Length: 27000, dtype: float64

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [[]
# Index: []

# %%
df
# Out:
#                                           [
#   {"Series":"I"    "X":10.0  "Y":8.04}  NaN
#                    "X":8.0   "Y":6.95}  NaN
#                    "X":13.0  "Y":7.58}  NaN
#                    "X":9.0   "Y":8.81}  NaN
#                    "X":11.0  "Y":8.33}  NaN
#                    "X":14.0  "Y":9.96}  NaN
#                    "X":6.0   "Y":7.24}  NaN
#                    "X":4.0   "Y":4.26}  NaN
#                    "X":12.0  "Y":10.84} NaN
#                    "X":7.0   "Y":4.81}  NaN
#                    "X":5.0   "Y":5.68}  NaN
#   {"Series":"II"   "X":10.0  "Y":9.14}  NaN
#                    "X":8.0   "Y":8.14}  NaN
#                    "X":13.0  "Y":8.74}  NaN
#                    "X":9.0   "Y":8.77}  NaN
#                    "X":11.0  "Y":9.26}  NaN
#                    "X":14.0  "Y":8.10}  NaN
#                    "X":6.0   "Y":6.13}  NaN
#                    "X":4.0   "Y":3.10}  NaN
#                    "X":12.0  "Y":9.13}  NaN
# ...

# %%
df.isnull()
# Out:
#                                             [
#   {"Series":"I"    "X":10.0  "Y":8.04}   True
#                    "X":8.0   "Y":6.95}   True
#                    "X":13.0  "Y":7.58}   True
#                    "X":9.0   "Y":8.81}   True
#                    "X":11.0  "Y":8.33}   True
#                    "X":14.0  "Y":9.96}   True
#                    "X":6.0   "Y":7.24}   True
#                    "X":4.0   "Y":4.26}   True
#                    "X":12.0  "Y":10.84}  True
#                    "X":7.0   "Y":4.81}   True
#                    "X":5.0   "Y":5.68}   True
#   {"Series":"II"   "X":10.0  "Y":9.14}   True
#                    "X":8.0   "Y":8.14}   True
#                    "X":13.0  "Y":8.74}   True
#                    "X":9.0   "Y":8.77}   True
#                    "X":11.0  "Y":9.26}   True
#                    "X":14.0  "Y":8.10}   True
#                    "X":6.0   "Y":6.13}   True
#                    "X":4.0   "Y":3.10}   True
# ...

# %%
f.groupby('latitude').sum()
# Out:
#           longitude  housing_median_age  total_rooms  total_bedrooms  \
# latitude
# 32.56       -117.09                 8.0        864.0           156.0
# 32.57       -351.31                85.0       6376.0          1386.0
# 32.58       -702.54               135.0       8977.0          1878.0
# 32.59       -234.18                41.0       6713.0          1481.0
# 32.60       -117.07                13.0       1607.0           435.0
# ...             ...                 ...          ...             ...
# 41.31       -122.32                45.0       1393.0           294.0
# 41.54       -123.92                22.0       2920.0           636.0
# 41.63       -122.64                19.0       2722.0           479.0
# 41.80       -124.17                16.0       2739.0           480.0
# 41.92       -124.16                19.0       1668.0           324.0
#
#           population  households  median_income  median_house_value
# latitude
# ...

# %%
y=f.groupby('total_rooms').min()

# %%
y
# Out:
#              longitude  latitude  housing_median_age  total_bedrooms  \
# total_rooms
# 6.0            -116.95     33.86                 1.0             2.0
# 16.0           -117.12     32.66                52.0             4.0
# 18.0           -114.62     33.62                26.0             3.0
# 19.0           -121.04     37.67                16.0            19.0
# 21.0           -118.06     34.03                36.0             7.0
# ...                ...       ...                 ...             ...
# 21988.0        -117.12     33.49                 4.0          4055.0
# 23915.0        -117.27     33.15                 4.0          4135.0
# 24121.0        -116.36     33.78                 6.0          4522.0
# 27870.0        -121.53     38.48                 5.0          5027.0
# 30450.0        -117.20     33.58                 2.0          5033.0
#
#              population  households  median_income  median_house_value
# total_rooms
# ...

# %%
avg=y['avg detail']=y['population']/y['households']

# %%
avg
# Out:
# total_rooms
# 6.0         4.000000
# 16.0        2.666667
# 18.0        1.666667
# 19.0       18.444444
# 21.0        2.333333
#              ...
# 21988.0     2.713407
# 23915.0     2.748105
# 24121.0     1.880234
# 27870.0     2.458290
# 30450.0     2.946200
# Length: 2215, dtype: float64

# %%
data = {
    'apples': [3, 2, 0, 1],
    'oranges': [0, 3, 7, 2]
}

# %%
q=pd.DataFrame(data)

# %%
q
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
q=pd.DataFrame(data, index=['June', 'Robert', 'Lily', 'David'])

# %%
q
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
q.loc['June']
# Out:
# apples     3
# oranges    0
# Name: June, dtype: int64

# %% [markdown]
# CSVs don't have indexes like our DataFrames, so all we need to do is just designate the index_col when reading:
#
# df = pd.read_csv('purchases.csv', index_col=0)

# %% [markdown]
# Converting back to a CSV, JSON, or SQL
# df.to_csv('new_purchases.csv')
#
# df.to_json('new_purchases.json')
#
# df.to_sql('new_purchases', con)

# %%
f.to_json('new.json')

# %%
df.shape
# Out:
# (45, 1)

# %%
temp_df=df.append(df)

# %%
temp_df.shape
# Out:
# (90, 1)

# %%
temp_df=temp_df.drop_duplicates()

# %%
temp_df.shape
# Out:
# (1, 1)

# %%
temp_df.drop_duplicates(inplace=True)

# %%
temp_df
# Out:
#                                        [
#   {"Series":"I"  "X":10.0  "Y":8.04} NaN

# %%
temp_df.drop_duplicates(inplace=False)
# Out:
#                                        [
#   {"Series":"I"  "X":10.0  "Y":8.04} NaN

# %% [markdown]
# Another important argument for drop_duplicates() is keep, which has three possible options:
#
# first: (default) Drop duplicates except for the first occurrence.
# last: Drop duplicates except for the last occurrence.
# False: Drop all duplicates.

# %%
df.drop_duplicates(keep="first")
# Out:
#                                        [
#   {"Series":"I"  "X":10.0  "Y":8.04} NaN

# %%
df.drop_duplicates(keep="last")
# Out:
#             [
# ] NaN NaN NaN

# %%
df.drop_duplicates(keep=False)
# Out:
# Empty DataFrame
# Columns: [[]
# Index: []

# %%
df.columns
# Out:
# Index(['['], dtype='object')

# %%
f.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
f.rename(columns={
    'longitude':'long',
    'latitude':'lat'
})
# Out:
#         long    lat  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05  37.37                27.0       3885.0           661.0
# 1    -118.30  34.26                43.0       1510.0           310.0
# 2    -117.81  33.78                27.0       3589.0           507.0
# 3    -118.36  33.82                28.0         67.0            15.0
# 4    -119.67  36.33                19.0       1241.0           244.0
# ...      ...    ...                 ...          ...             ...
# 2995 -119.86  34.42                23.0       1450.0           642.0
# 2996 -118.14  34.06                27.0       5257.0          1082.0
# 2997 -119.70  36.30                10.0        956.0           201.0
# 2998 -117.12  34.10                40.0         96.0            14.0
# 2999 -119.63  34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# ...

# %%
f.columns=[col.upper() for col in f]

# %%
f.columns
# Out:
# Index(['LONGITUDE', 'LATITUDE', 'HOUSING_MEDIAN_AGE', 'TOTAL_ROOMS',
#        'TOTAL_BEDROOMS', 'POPULATION', 'HOUSEHOLDS', 'MEDIAN_INCOME',
#        'MEDIAN_HOUSE_VALUE'],
#       dtype='object')

# %%
f.isnull()
# Out:
#       LONGITUDE  LATITUDE  HOUSING_MEDIAN_AGE  TOTAL_ROOMS  TOTAL_BEDROOMS  \
# 0         False     False               False        False           False
# 1         False     False               False        False           False
# 2         False     False               False        False           False
# 3         False     False               False        False           False
# 4         False     False               False        False           False
# ...         ...       ...                 ...          ...             ...
# 2995      False     False               False        False           False
# 2996      False     False               False        False           False
# 2997      False     False               False        False           False
# 2998      False     False               False        False           False
# 2999      False     False               False        False           False
#
#       POPULATION  HOUSEHOLDS  MEDIAN_INCOME  MEDIAN_HOUSE_VALUE
# ...

# %%
f.isnull().sum()
# Out:
# LONGITUDE             0
# LATITUDE              0
# HOUSING_MEDIAN_AGE    0
# TOTAL_ROOMS           0
# TOTAL_BEDROOMS        0
# POPULATION            0
# HOUSEHOLDS            0
# MEDIAN_INCOME         0
# MEDIAN_HOUSE_VALUE    0
# dtype: int64

# %% [markdown]
# dropna() used for dropping null values

# %%
f.describe()
# Out:
#          LONGITUDE    LATITUDE  HOUSING_MEDIAN_AGE   TOTAL_ROOMS  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        TOTAL_BEDROOMS    POPULATION  HOUSEHOLDS  MEDIAN_INCOME  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
f['LONGITUDE'].describe()
# Out:
# count    3000.000000
# mean     -119.589200
# std         1.994936
# min      -124.180000
# 25%      -121.810000
# 50%      -118.485000
# 75%      -118.020000
# max      -114.490000
# Name: LONGITUDE, dtype: float64

# %% [markdown]
# .value_counts() can tell us the frequency of all values in a column

# %%
f.value_counts()
# Out:
# LONGITUDE  LATITUDE  HOUSING_MEDIAN_AGE  TOTAL_ROOMS  TOTAL_BEDROOMS  POPULATION  HOUSEHOLDS  MEDIAN_INCOME  MEDIAN_HOUSE_VALUE
# -124.18    40.79     40.0                1398.0       311.0           788.0       279.0       1.4668         64600.0               1
# -118.20    33.98     43.0                1091.0       320.0           1418.0      316.0       2.1522         159400.0              1
#            33.78     48.0                1766.0       497.0           1908.0      466.0       1.9872         168800.0              1
#            33.80     45.0                2456.0       495.0           1300.0      450.0       3.9792         210200.0              1
#            33.82     34.0                2807.0       768.0           2217.0      744.0       2.4286         204800.0              1
#                                                                                                                                   ..
# ...

# %%
f.corr()
# Out:
#                     LONGITUDE  LATITUDE  HOUSING_MEDIAN_AGE  TOTAL_ROOMS  \
# LONGITUDE            1.000000 -0.925017           -0.064203     0.049865
# LATITUDE            -0.925017  1.000000           -0.025143    -0.039632
# HOUSING_MEDIAN_AGE  -0.064203 -0.025143            1.000000    -0.367850
# TOTAL_ROOMS          0.049865 -0.039632           -0.367850     1.000000
# TOTAL_BEDROOMS       0.070869 -0.068245           -0.323154     0.937749
# POPULATION           0.111572 -0.117318           -0.299888     0.838867
# HOUSEHOLDS           0.051062 -0.068296           -0.305171     0.914116
# MEDIAN_INCOME       -0.018701 -0.072363           -0.144315     0.221249
# MEDIAN_HOUSE_VALUE  -0.050662 -0.138428            0.091409     0.160427
#
#                     TOTAL_BEDROOMS  POPULATION  HOUSEHOLDS  MEDIAN_INCOME  \
# LONGITUDE                 0.070869    0.111572    0.051062      -0.018701
# LATITUDE                 -0.068245   -0.117318   -0.068296      -0.072363
# ...

# %%
we=f['LONGITUDE']
type(we)
# Out:
# pandas.core.series.Series

# %%
we
# Out:
# 0      -122.05
# 1      -118.30
# 2      -117.81
# 3      -118.36
# 4      -119.67
#          ...
# 2995   -119.86
# 2996   -118.14
# 2997   -119.70
# 2998   -117.12
# 2999   -119.63
# Name: LONGITUDE, Length: 3000, dtype: float64

# %%
we=f[['LONGITUDE']]
type(we)
# Out:
# pandas.core.frame.DataFrame

# %%
we
# Out:
#       LONGITUDE
# 0       -122.05
# 1       -118.30
# 2       -117.81
# 3       -118.36
# 4       -119.67
# ...         ...
# 2995    -119.86
# 2996    -118.14
# 2997    -119.70
# 2998    -117.12
# 2999    -119.63
#
# [3000 rows x 1 columns]

# %%
wef=f[['LONGITUDE','LATITUDE']]
type(we)
# Out:
# pandas.core.frame.DataFrame

# %%
wef
# Out:
#       LONGITUDE  LATITUDE
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %% [markdown]
# .loc - locates by name
#      ,    .iloc- locates by numerical index

# %%
ee=wef.loc[2888]

# %%
ee
# Out:
# LONGITUDE   -117.21
# LATITUDE      32.74
# Name: 2888, dtype: float64

# %%
rt=wef.iloc[234:256]

# %%
rt
# Out:
#      LONGITUDE  LATITUDE
# 234    -122.00     37.35
# 235    -119.02     35.41
# 236    -118.13     34.18
# 237    -121.94     37.27
# 238    -120.51     35.91
# 239    -121.65     38.03
# 240    -121.62     39.79
# 241    -117.08     32.82
# 242    -123.21     39.14
# 243    -119.61     36.33
# 244    -114.98     33.07
# 245    -118.38     34.04
# 246    -117.99     33.70
# 247    -116.26     33.72
# 248    -118.40     34.00
# 249    -120.64     35.46
# 250    -122.03     37.39
# 251    -118.29     33.88
# 252    -117.02     32.69
# 253    -119.32     36.30
# 254    -122.31     38.01
# 255    -118.86     34.19

# %%
condition=[f['LATITUDE']>38]

# %%
condition
# Out:
# [0       False
#  1       False
#  2       False
#  3       False
#  4       False
#          ...
#  2995    False
#  2996    False
#  2997    False
#  2998    False
#  2999    False
#  Name: LATITUDE, Length: 3000, dtype: bool]

# %%
f[f['MEDIAN_HOUSE_VALUE']>177000].head(2)
# Out:
#    LONGITUDE  LATITUDE  HOUSING_MEDIAN_AGE  TOTAL_ROOMS  TOTAL_BEDROOMS  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 2    -117.81     33.78                27.0       3589.0           507.0
#
#    POPULATION  HOUSEHOLDS  MEDIAN_INCOME  MEDIAN_HOUSE_VALUE
# 0      1537.0       606.0         6.6085            344700.0
# 2      1484.0       495.0         5.7934            270500.0

# %% [markdown]
# logical operators | for "or" and & for "and"

# %%
f[(f['LATITUDE' ]>38)|(f['TOTAL_BEDROOMS']>660)].head()
# Out:
#     LONGITUDE  LATITUDE  HOUSING_MEDIAN_AGE  TOTAL_ROOMS  TOTAL_BEDROOMS  \
# 0     -122.05     37.37                27.0       3885.0           661.0
# 6     -121.43     38.63                43.0       1009.0           225.0
# 8     -122.84     38.40                15.0       3080.0           617.0
# 13    -117.03     32.97                16.0       3936.0           694.0
# 17    -121.20     38.69                26.0       3077.0           607.0
#
#     POPULATION  HOUSEHOLDS  MEDIAN_INCOME  MEDIAN_HOUSE_VALUE
# 0       1537.0       606.0         6.6085            344700.0
# 6        604.0       218.0         1.6641             67000.0
# 8       1446.0       599.0         3.6696            194400.0
# 13      1935.0       659.0         4.5625            231200.0
# 17      1603.0       595.0         2.7174            137500.0

# %%
f[(f['LATITUDE' ]>38)&(f['TOTAL_BEDROOMS']>660)].head()
# Out:
#      LONGITUDE  LATITUDE  HOUSING_MEDIAN_AGE  TOTAL_ROOMS  TOTAL_BEDROOMS  \
# 19     -122.59     38.01                35.0       8814.0          1307.0
# 32     -121.13     39.31                17.0       3442.0           705.0
# 83     -122.05     38.26                21.0       7195.0          1416.0
# 149    -121.64     39.28                25.0       2857.0           662.0
# 239    -121.65     38.03                28.0       3144.0           694.0
#
#      POPULATION  HOUSEHOLDS  MEDIAN_INCOME  MEDIAN_HOUSE_VALUE
# 19       3450.0      1258.0         6.1724            414300.0
# 32       1693.0       619.0         2.8102            128900.0
# 83       3927.0      1377.0         3.0912            126300.0
# 149      2076.0       685.0         1.8095             64100.0
# 239      1095.0       482.0         3.4402            192400.0

# %% [markdown]
# isin() helps in retrieving two conditional claused datas by single argument passing

# %% [markdown]
# apply() used to implement the defined function t act on the df to built new or modify something

# %% [markdown]
# Visualize with descired plots
